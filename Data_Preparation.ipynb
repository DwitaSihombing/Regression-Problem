# %% [markdown]
# # Kelompok 5

# %% [markdown]
# * Ignatia Hutagalung			12S19043
# * Dwita Sihombing			12S19055
# * Putri Yohana Rajagukguk		12S19056

# %% [markdown]
# # Memilah Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/case_cost_prediction_train.csv")

# %%
data.isnull()
# Out:
#        row_id  tglpelayanan  kddati2    tkp  peserta      a      b      c  \
# 0       False         False    False  False    False  False  False  False
# 1       False         False    False  False    False  False  False  False
# 2       False         False    False  False    False  False  False  False
# 3       False         False    False  False    False  False  False  False
# 4       False         False    False  False    False  False  False  False
# ...       ...           ...      ...    ...      ...    ...    ...    ...
# 52530   False         False    False  False    False  False  False  False
# 52531   False         False    False  False    False  False  False  False
# 52532   False         False    False  False    False  False  False  False
# 52533   False         False    False  False    False  False  False  False
# 52534   False         False     True   True     True   True   True   True
#
#           cb      d  ...     kp     kt     ku      s     sa     sb     sc  \
# ...

# %%
data.isnull().sum()
# Out:
# row_id          0
# tglpelayanan    0
# kddati2         1
# tkp             1
# peserta         1
# a               1
# b               1
# c               1
# cb              1
# d               1
# ds              1
# gd              1
# hd              1
# i1              1
# i2              1
# i3              1
# i4              1
# kb              1
# kc              1
# kg              1
# ki              1
# kj              1
# kk              1
# kl              1
# km              1
# ko              1
# kp              1
# kt              1
# ku              1
# s               1
# sa              1
# sb              1
# sc              1
# sd              1
# case            1
# unit_cost       1
# dtype: int64

# %% [markdown]
# ## Cleaning Data

# %%
data.nunique()
# Out:
# row_id          52535
# tglpelayanan       91
# kddati2           490
# tkp                 2
# peserta         34797
# a                   3
# b                   9
# c                   7
# cb                  2
# d                   6
# ds                  1
# gd                 11
# hd                  7
# i1                  2
# i2                  3
# i3                  4
# i4                  4
# kb                  3
# kc                  2
# kg                  5
# ki                 12
# kj                  3
# kk                  2
# kl                  7
# km                  7
# ko                  2
# kp                  3
# kt                  2
# ku                  2
# s                   6
# sa                  2
# sb                 10
# sc                 25
# sd                 11
# case            14511
# unit_cost       52511
# dtype: int64

# %% [markdown]
# # Mengkonstruksikan Data

# %%
import pandas as pd

# %%
case_cost_prediction_train = pd.read_csv("/content/case_cost_prediction_train.csv")

# %%
case_cost_prediction_train
# Out:
#        row_id         tglpelayanan  kddati2  tkp  peserta  a  b  c  cb  d  \
# 0           1  2014-04-01 00:00:00      332   40   179530  0  0  1   0  1
# 1           2  2016-11-01 00:00:00       54   40   104782  0  1  0   0  0
# 2           3  2016-05-01 00:00:00      323   30   280645  0  0  1   0  0
# 3           4  2018-11-01 00:00:00      318   40   178685  0  1  0   0  0
# 4           5  2019-10-01 00:00:00      150   30  1199321  1  0  1   0  0
# ...       ...                  ...      ...  ...      ... .. .. ..  .. ..
# 57966   57967  2019-03-01 00:00:00      241   40   157213  0  0  1   0  0
# 57967   57968  2019-09-01 00:00:00      338   30   402173  0  0  1   0  0
# 57968   57969  2016-06-01 00:00:00      241   40    99401  0  0  1   0  0
# 57969   57970  2018-01-01 00:00:00      147   40   509495  0  0  1   0  0
# 57970   57971  2016-09-01 00:00:00      204   30   770169  0  1  1   0  0
#
#        ...  kp  kt  ku  s  sa  sb  sc  sd   case     unit_cost
# ...

# %% [markdown]
# merubah nilai tglpelayanan dengan label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
case_cost_prediction_train['tglpelayanan'] = encoder.fit_transform(case_cost_prediction_train ['tglpelayanan'])

# %%
case_cost_prediction_train
# Out:
#        row_id  tglpelayanan  kddati2  tkp  peserta  a  b  c  cb  d  ...  kp  \
# 0           1             3      332   40   179530  0  0  1   0  1  ...   0
# 1           2            34       54   40   104782  0  1  0   0  0  ...   0
# 2           3            28      323   30   280645  0  0  1   0  0  ...   0
# 3           4            58      318   40   178685  0  1  0   0  0  ...   0
# 4           5            69      150   30  1199321  1  0  1   0  0  ...   1
# ...       ...           ...      ...  ...      ... .. .. ..  .. ..  ...  ..
# 57966   57967            62      241   40   157213  0  0  1   0  0  ...   0
# 57967   57968            68      338   30   402173  0  0  1   0  0  ...   0
# 57968   57969            29      241   40    99401  0  0  1   0  0  ...   0
# 57969   57970            48      147   40   509495  0  0  1   0  0  ...   0
# 57970   57971            32      204   30   770169  0  1  1   0  0  ...   0
#
#        kt  ku  s  sa  sb  sc  sd   case     unit_cost
# ...

# %% [markdown]
# berdasarkan output dapat kita lihat bahwa tglpelayanan sudah berubah menjadi angka

# %%
plt.figure(figsize=(40,30))
sns.heatmap(data.corr(), annot=True, linewidth = 1.5, cmap='coolwarm')

# %% [markdown]
# # Melabelkan Data

# %% [markdown]
# Proses label data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
case_cost_prediction_train['case'].describe()
# Out:
# count     57971.000000
# mean       6539.418451
# std       17607.280021
# min           1.000000
# 25%         424.000000
# 50%        1359.000000
# 75%        4583.000000
# max      333441.000000
# Name: case, dtype: float64

# %%
case_cost_prediction_train['unit_cost'].describe()
# Out:
# count    5.797100e+04
# mean     1.961092e+06
# std      1.889367e+06
# min      1.000000e+05
# 25%      2.336742e+05
# 50%      6.547994e+05
# 75%      3.531702e+06
# max      2.690550e+07
# Name: unit_cost, dtype: float64

# %%
case_cost_prediction_train = case_cost_prediction_train.drop(['row_id', 'a', 'b', 'c', 'cb', 'd', 'ds', 'gd', 'hd', 'i1', 'i2', 'i3', 'i4', 'kb', 'kc', 'kg', 'ki', 'kj', 'kk', 'kl', 'km', 'ko', 'kp', 'kt', 'ku', 's', 'sa', 'sb','sc', 'sd'],axis=1)
print(case_cost_prediction_train)
# Out:
#        tglpelayanan  kddati2  tkp  peserta   case     unit_cost
# 0                 3      332   40   179530    266  3.597440e+06
# 1                34       54   40   104782   2453  4.951008e+06
# 2                28      323   30   280645   1690  1.984208e+05
# 3                58      318   40   178685   1321  4.008756e+06
# 4                69      150   30  1199321  73056  3.072272e+05
# ...             ...      ...  ...      ...    ...           ...
# 57966            62      241   40   157213    410  3.443332e+06
# 57967            68      338   30   402173   8272  2.128621e+05
# 57968            29      241   40    99401    294  3.028611e+06
# 57969            48      147   40   509495   1983  3.629365e+06
# 57970            32      204   30   770169  16679  2.956852e+05
#
# [57971 rows x 6 columns]

# %%
# melabeli data training dan data evaluation

X = case_cost_prediction_train[['tglpelayanan', 'kddati2', 'tkp', 'unit_cost']]
y =case_cost_prediction_train[['peserta', 'case']]

# %% [markdown]
# #Integrasi Data

# %%
import pandas as pd

# %%
print(case_cost_prediction_train)
# Out:
#        tglpelayanan  kddati2  tkp  peserta   case     unit_cost
# 0                 3      332   40   179530    266  3.597440e+06
# 1                34       54   40   104782   2453  4.951008e+06
# 2                28      323   30   280645   1690  1.984208e+05
# 3                58      318   40   178685   1321  4.008756e+06
# 4                69      150   30  1199321  73056  3.072272e+05
# ...             ...      ...  ...      ...    ...           ...
# 57966            62      241   40   157213    410  3.443332e+06
# 57967            68      338   30   402173   8272  2.128621e+05
# 57968            29      241   40    99401    294  3.028611e+06
# 57969            48      147   40   509495   1983  3.629365e+06
# 57970            32      204   30   770169  16679  2.956852e+05
#
# [57971 rows x 6 columns]

# %%
row_concat = pd.concat([case_cost_prediction_train])

# %%
print(row_concat.iloc[3,])
# Out:
# tglpelayanan    5.800000e+01
# kddati2         3.180000e+02
# tkp             4.000000e+01
# peserta         1.786850e+05
# case            1.321000e+03
# unit_cost       4.008756e+06
# Name: 3, dtype: float64

# %%
new_row_series = pd.Series(['n1', 'n2', 'n3', 'n4'])
print(new_row_series)
# Out:
# 0    n1
# 1    n2
# 2    n3
# 3    n4
# dtype: object

# %%
# attempt to add the new row to a dataframe
print(pd.concat([case_cost_prediction_train, new_row_series]))
# Out:
#          0     case  kddati2    peserta  tglpelayanan   tkp     unit_cost
# 0      NaN    266.0    332.0   179530.0           3.0  40.0  3.597440e+06
# 1      NaN   2453.0     54.0   104782.0          34.0  40.0  4.951008e+06
# 2      NaN   1690.0    323.0   280645.0          28.0  30.0  1.984208e+05
# 3      NaN   1321.0    318.0   178685.0          58.0  40.0  4.008756e+06
# 4      NaN  73056.0    150.0  1199321.0          69.0  30.0  3.072272e+05
# ...    ...      ...      ...        ...           ...   ...           ...
# 57970  NaN  16679.0    204.0   770169.0          32.0  30.0  2.956852e+05
# 0       n1      NaN      NaN        NaN           NaN   NaN           NaN
# 1       n2      NaN      NaN        NaN           NaN   NaN           NaN
# 2       n3      NaN      NaN        NaN           NaN   NaN           NaN
# 3       n4      NaN      NaN        NaN           NaN   NaN           NaN
#
# [57975 rows x 7 columns]

# %%
# note the double brackets
new_row_df = pd.DataFrame([['n1', 'n2', 'n3', 'n4']], columns=['A', 'B', 'C', 'D'])
print(new_row_df)
# Out:
#     A   B   C   D
# 0  n1  n2  n3  n4

# %%
print(pd.concat([case_cost_prediction_train, new_row_df]))
# Out:
#        tglpelayanan  kddati2   tkp    peserta     case     unit_cost    A  \
# 0               3.0    332.0  40.0   179530.0    266.0  3.597440e+06  NaN
# 1              34.0     54.0  40.0   104782.0   2453.0  4.951008e+06  NaN
# 2              28.0    323.0  30.0   280645.0   1690.0  1.984208e+05  NaN
# 3              58.0    318.0  40.0   178685.0   1321.0  4.008756e+06  NaN
# 4              69.0    150.0  30.0  1199321.0  73056.0  3.072272e+05  NaN
# ...             ...      ...   ...        ...      ...           ...  ...
# 57967          68.0    338.0  30.0   402173.0   8272.0  2.128621e+05  NaN
# 57968          29.0    241.0  40.0    99401.0    294.0  3.028611e+06  NaN
# 57969          48.0    147.0  40.0   509495.0   1983.0  3.629365e+06  NaN
# 57970          32.0    204.0  30.0   770169.0  16679.0  2.956852e+05  NaN
# 0               NaN      NaN   NaN        NaN      NaN           NaN   n1
#
#          B    C    D
# 0      NaN  NaN  NaN
# 1      NaN  NaN  NaN
# ...

# %%
data_dict = {'A': 'n1',
             'B': 'n2',
             'C': 'n3',
             'D': 'n4'}

print(case_cost_prediction_train.append(data_dict, ignore_index=True))
# Out:
#        tglpelayanan  kddati2   tkp    peserta     case     unit_cost    A  \
# 0               3.0    332.0  40.0   179530.0    266.0  3.597440e+06  NaN
# 1              34.0     54.0  40.0   104782.0   2453.0  4.951008e+06  NaN
# 2              28.0    323.0  30.0   280645.0   1690.0  1.984208e+05  NaN
# 3              58.0    318.0  40.0   178685.0   1321.0  4.008756e+06  NaN
# 4              69.0    150.0  30.0  1199321.0  73056.0  3.072272e+05  NaN
# ...             ...      ...   ...        ...      ...           ...  ...
# 57967          68.0    338.0  30.0   402173.0   8272.0  2.128621e+05  NaN
# 57968          29.0    241.0  40.0    99401.0    294.0  3.028611e+06  NaN
# 57969          48.0    147.0  40.0   509495.0   1983.0  3.629365e+06  NaN
# 57970          32.0    204.0  30.0   770169.0  16679.0  2.956852e+05  NaN
# 57971           NaN      NaN   NaN        NaN      NaN           NaN   n1
#
#          B    C    D
# 0      NaN  NaN  NaN
# 1      NaN  NaN  NaN
# ...

# %%
row_concat_i = pd.concat([case_cost_prediction_train], ignore_index=True)
print(row_concat_i)
# Out:
#        tglpelayanan  kddati2  tkp  peserta   case     unit_cost
# 0                 3      332   40   179530    266  3.597440e+06
# 1                34       54   40   104782   2453  4.951008e+06
# 2                28      323   30   280645   1690  1.984208e+05
# 3                58      318   40   178685   1321  4.008756e+06
# 4                69      150   30  1199321  73056  3.072272e+05
# ...             ...      ...  ...      ...    ...           ...
# 57966            62      241   40   157213    410  3.443332e+06
# 57967            68      338   30   402173   8272  2.128621e+05
# 57968            29      241   40    99401    294  3.028611e+06
# 57969            48      147   40   509495   1983  3.629365e+06
# 57970            32      204   30   770169  16679  2.956852e+05
#
# [57971 rows x 6 columns]

# %% [markdown]
# #Adding Columns

# %%
col_concat = pd.concat([case_cost_prediction_train], axis=1)
print(col_concat)
# Out:
#        tglpelayanan  kddati2  tkp  peserta   case     unit_cost
# 0                 3      332   40   179530    266  3.597440e+06
# 1                34       54   40   104782   2453  4.951008e+06
# 2                28      323   30   280645   1690  1.984208e+05
# 3                58      318   40   178685   1321  4.008756e+06
# 4                69      150   30  1199321  73056  3.072272e+05
# ...             ...      ...  ...      ...    ...           ...
# 57966            62      241   40   157213    410  3.443332e+06
# 57967            68      338   30   402173   8272  2.128621e+05
# 57968            29      241   40    99401    294  3.028611e+06
# 57969            48      147   40   509495   1983  3.629365e+06
# 57970            32      204   30   770169  16679  2.956852e+05
#
# [57971 rows x 6 columns]

# %%
print(pd.concat([case_cost_prediction_train], axis=1, ignore_index=True))
# Out:
#         0    1   2        3      4             5
# 0       3  332  40   179530    266  3.597440e+06
# 1      34   54  40   104782   2453  4.951008e+06
# 2      28  323  30   280645   1690  1.984208e+05
# 3      58  318  40   178685   1321  4.008756e+06
# 4      69  150  30  1199321  73056  3.072272e+05
# ...    ..  ...  ..      ...    ...           ...
# 57966  62  241  40   157213    410  3.443332e+06
# 57967  68  338  30   402173   8272  2.128621e+05
# 57968  29  241  40    99401    294  3.028611e+06
# 57969  48  147  40   509495   1983  3.629365e+06
# 57970  32  204  30   770169  16679  2.956852e+05
#
# [57971 rows x 6 columns]

# %% [markdown]
# #Adding Rows

# %%
row_concat = pd.concat([case_cost_prediction_train], sort=False)
print(row_concat)
# Out:
#        tglpelayanan  kddati2  tkp  peserta   case     unit_cost
# 0                 3      332   40   179530    266  3.597440e+06
# 1                34       54   40   104782   2453  4.951008e+06
# 2                28      323   30   280645   1690  1.984208e+05
# 3                58      318   40   178685   1321  4.008756e+06
# 4                69      150   30  1199321  73056  3.072272e+05
# ...             ...      ...  ...      ...    ...           ...
# 57966            62      241   40   157213    410  3.443332e+06
# 57967            68      338   30   402173   8272  2.128621e+05
# 57968            29      241   40    99401    294  3.028611e+06
# 57969            48      147   40   509495   1983  3.629365e+06
# 57970            32      204   30   770169  16679  2.956852e+05
#
# [57971 rows x 6 columns]

# %%
print(pd.concat([case_cost_prediction_train], join='inner'))
# Out:
#        tglpelayanan  kddati2  tkp  peserta   case     unit_cost
# 0                 3      332   40   179530    266  3.597440e+06
# 1                34       54   40   104782   2453  4.951008e+06
# 2                28      323   30   280645   1690  1.984208e+05
# 3                58      318   40   178685   1321  4.008756e+06
# 4                69      150   30  1199321  73056  3.072272e+05
# ...             ...      ...  ...      ...    ...           ...
# 57966            62      241   40   157213    410  3.443332e+06
# 57967            68      338   30   402173   8272  2.128621e+05
# 57968            29      241   40    99401    294  3.028611e+06
# 57969            48      147   40   509495   1983  3.629365e+06
# 57970            32      204   30   770169  16679  2.956852e+05
#
# [57971 rows x 6 columns]

# %% [markdown]
# #Concatenate Columns with Different Rows

# %%
col_concat = pd.concat([case_cost_prediction_train], axis=1)
print(col_concat)
# Out:
#        tglpelayanan  kddati2  tkp  peserta   case     unit_cost
# 0                 3      332   40   179530    266  3.597440e+06
# 1                34       54   40   104782   2453  4.951008e+06
# 2                28      323   30   280645   1690  1.984208e+05
# 3                58      318   40   178685   1321  4.008756e+06
# 4                69      150   30  1199321  73056  3.072272e+05
# ...             ...      ...  ...      ...    ...           ...
# 57966            62      241   40   157213    410  3.443332e+06
# 57967            68      338   30   402173   8272  2.128621e+05
# 57968            29      241   40    99401    294  3.028611e+06
# 57969            48      147   40   509495   1983  3.629365e+06
# 57970            32      204   30   770169  16679  2.956852e+05
#
# [57971 rows x 6 columns]
